# %% [markdown]
# # 順天堂大学データサイエンス学部「データビジュアライゼーション入門」
# ## -2023年1月6日-
# ### 各セル左上の［　］をクリックすることで各セルを順番に実行していくことができます
# ### 最初だけ「このノートブックは Google が作成したものではありません」と警告が出ますが心配はありません
# ### 「このまま実行」をクリックし先に進んでください

# %%
# !pip install japanize_matplotlib
# %matplotlib inline
import math
import numpy as np
import pandas as pd
from matplotlib import pylab as plt
import japanize_matplotlib
import sympy

# %% [markdown]
# ## まず最初に基本中の基本である棒グラフを描いてみます

# %%
smap_name = ['中居', '木村', '稲垣', '草彅', '香取']
smap_height = np.array([165, 176, 172, 170, 183])
plt.bar(smap_name, smap_height)

# %% [markdown]
# ## このように簡単な棒グラフはわずか３行のプログラムで作図できます
# - １行目でSMAPのメンバー名をデータとして与えています
# - ２行目でSMAPの５人の身長をデータとして与えています
# - ３行目で棒グラフを作図しています
#
# ### 棒グラフは軸が１つしかありませんでした
# ### データも１種類だけでした
# ## 次はもう少し複雑なグラフを描画したいと思います
# ## データの種類を増やし、軸の数も増やし、散布図を作成します

# %%
df_npb = pd.DataFrame(data={'身長': [184,182,187,188,180,180,183,167,183,172,183,179,175,171,171,182,180,175,184,181,182,175,178,183,185,186,175,193,182,175,182,193,179,191,178,178,182,176,178,177,171,179,177,178,180,178,185,180,184,180,188,182,186,188,174,172,178,179,175,175,170,188,174,185,179,175,195,173,181,182,177,185,183,184,181,183,180,197,184,188,178,174,181,189,182,189,185,184,173,174,193,184,193,176,178,184,199,183,191,185,188,180,183,183,175,185,178,186,173,176,180,173,173,172,177,176,179,181,175,187,177,185,175,184,178,171,180,175,178,192,182,171,188,181,189,182,188,176,176,177,180,183,185,183,181,187,186,181,187,188,180,183,188,178,175,190,182,183,188,186,178,178,193,174,175,185,183,183,182,190,181,173,185,184,170,186,186,175,188,178,187,176,177,175,179,172,172,177,180,186,184,186,183,180,182,178,181,200,182,178,176,178,177,173,180,196,178,183,181,173,196,180,187,178,175,187,177,185,180,177,178,186,188,173,189,181,190,179,181,178,180,176,190,180,180,176,181,196,182,173,182,177,186,184,193,186,194,181,175,176,180,178,173,188,177,175,170,171,181,183,190,171,174,182,178,178,175,171,167,180,184,180,185,180,183,188,176,180,178,176,177,180,181,180,167,189,180,187,186,178,183,183,187,178,177,186,175,181,180,178,183,181,178,184,184,177,167,185,179,184,180,193,188,177,183,179,180,180,190,181,185,188,177,184,186,180,185,181,177,180,179,181,176,184,185,175,190,180,182,177,176,182,180,179,172,184,174,185,183,175,182,170,187,182,180,183,181,175,185,179,180,178,187,173,182,175,182,190,188,178,183,177,196,193,179,180,182,190,175,182,178,180,188,178,186,178,185,181,178,179,180,176,176,175,180,174,178,175,182,180,177,177,167,180,178,176,172,185,182,174,185,180,188,174,178,179,
df_p48[['身長', '体重']].plot(kind='scatter', x='身長', y='体重', color='red', alpha=0.3, ax=ax)

# %% [markdown]
# ## 散布図もわずか４行のプログラムで作図できます
# - １行目で野球選手の身長と体重をデータとして与えています
# - ２行目で野球選手の身長と体重の散布図を作図しています。野球選手のデータは青いマーカーで示されています
# - ３行目で女性アイドルの身長と体重をデータとして与えています
# - ４行目で女性アイドルの身長と体重の散布図を作図しています。女性アイドルのデータは赤いマーカーで示されています
# - 散布図にはX軸とY軸の２つの軸があります。
# - この散布図では横軸（X軸）が身長、縦軸（Y軸）が体重になります。
# - 散布図を使うことで、野球選手の身長と体重、女性アイドルの身長と体重、合計４種類のデータの分布をわかりやすく図示することができました。
#
# ## データがあれば平均値と標準偏差を計算できます
# - 平均値とは、数の集合やデータの中間的な値のことです。
# - 標準偏差とは、データの平均値からの散らばり具合（ばらつき）のことです。
# ## 野球選手と女性アイドルの身長と体重のデータから、平均値と標準偏差を計算します

# %%
npb_height_mean = df_npb['身長'].mean()
npb_height_std = df_npb['身長'].std()
npb_weight_mean = df_npb['体重'].mean()
npb_weight_std = df_npb['体重'].std()
p48_height_mean = df_p48['身長'].mean()
p48_height_std = df_p48['身長'].std()
p48_weight_mean = df_p48['体重'].mean()
p48_weight_std = df_p48['体重'].std()
print(f'野球選手の身長の平均は{npb_height_mean}、標準偏差は{npb_height_std}です')
print(f'女性アイドルの身長の平均は{p48_height_mean}、標準偏差は{p48_height_std}です')
print(f'野球選手の体重の平均は{npb_weight_mean}、標準偏差は{npb_weight_std}です')
print(f'女性アイドルの体重の平均は{p48_weight_mean}、標準偏差は{p48_weight_std}です')

# %% [markdown]
# ## 平均値と標準偏差の２つさえあれば（元になったデータが無くても）偏差値を計算できます
# ### 大谷翔平選手の身長と体重（193cm、93kg）を使って、大谷翔平選手の身長偏差値と体重偏差値を計算します
# - 下のセル内の数字は自由に編集できます。余裕があれば（自分の理想の）身長と体重を入力し再計算してみましょう。

# %%
my_height = 193
my_weight = 93

# %%
df_me = pd.DataFrame(
    data={'身長': [my_height], 
          '体重': [my_weight],}
)
ax = df_npb[['身長', '体重']].plot(kind='scatter', x='身長', y='体重', color='blue', alpha=0.3, title='野球選手と女性アイドルの身長体重分布（青=野球選手、赤=女性アイドル）')
df_p48[['身長', '体重']].plot(kind='scatter', x='身長', y='体重', color='red', alpha=0.3, ax=ax)
df_me[['身長', '体重']].plot(kind='scatter', x='身長', y='体重', color='green', alpha=0.8, ax=ax, s=200)
deviation_value_npb_height = int((my_height - npb_height_mean) / npb_height_std * 10 + 50)
deviation_value_npb_weight = int((my_weight - npb_weight_mean) / npb_weight_std * -10 + 50)
deviation_value_p48_height = int((my_height - p48_height_mean) / p48_height_std * 10 + 50)
deviation_value_p48_weight = int((my_weight - p48_weight_mean) / p48_weight_std * -10 + 50)

# %%
print(f'私が野球選手の中に入ると身長偏差値は{deviation_value_npb_height}、体重偏差値は{deviation_value_npb_weight}')
print(f'私が女性アイドルの中に入ると身長偏差値は{deviation_value_p48_height}、体重偏差値は{deviation_value_p48_weight}')

# %% [markdown]
# ここまでで、平均、標準偏差、偏差値を計算し簡単にグラフにできることをお示ししました。
#
# ここからは、高校数学の最難関（かもしれない）微分と積分を計算しグラフにしていきます。
#
# 方程式をグラフに描いていきます。$$\int_1^2 (9x^2-4x+3)dx$$

# %%
y_val = []
integral_y = []
for i in np.arange(-3, 3, 0.1):
    y_val.append(9 * i ** 2 - 4 * i + 3)
for i in np.arange(1, 2.1, 0.1):
    integral_y.append(9 * i ** 2 - 4 * i + 3)
plt.plot(np.arange(-3, 3, 0.1), y_val, color='blue', label="f(x)")
plt.axhline(y=0, color="gray")
plt.axvline(x=0, color="gray")
plt.fill_between(np.arange(1, 2.1, 0.1), integral_y, facecolor='red')
plt.show()

# %% [markdown]
# グラフが描けたら方程式を計算します。$$\int_1^2 (9x^2-4x+3)dx$$

# %%
x = sympy.Symbol('x')
print(sympy.integrate(9 * x ** 2 - 4 * x + 3, (x, 1, 2)))

# %% [markdown]
# 方程式をグラフに描いていきます。$$\int_1^3 (3x-1)(x+1)dx$$

# %%
y_val = []
integral_y = []
for i in np.arange(-4, 4, 0.1):
    y_val.append((3 * i - 1) * (i + 1))
for i in np.arange(1, 3.1, 0.1):
    integral_y.append((3 * i - 1) * (i + 1))
plt.plot(np.arange(-4, 4, 0.1), y_val, color='blue', label="f(x)")
plt.axhline(y=0, color="gray")
plt.axvline(x=0, color="gray")
plt.fill_between(np.arange(1, 3.1, 0.1), integral_y, facecolor='red')
plt.show()

# %% [markdown]
# グラフが描けたら方程式を計算します。$$\int_1^3 (3x-1)(x+1)dx$$

# %%
print(sympy.integrate((3 * x - 1) * (x + 1), (x, 1, 3)))

# %% [markdown]
# 方程式をグラフに描いていきます。$$\int_{-1}^2 (\frac{8}{3}x^3+x-1)dx$$

# %%
y_val = []
integral_y = []
for i in np.arange(-3, 3, 0.1):
    y_val.append((8 / 3) * i ** 3 + i - 1)
for i in np.arange(-1, 2, 0.1):
    integral_y.append((8 / 3) * i ** 3 + i - 1)
plt.plot(np.arange(-3, 3, 0.1), y_val, color='blue', label="f(x)")
plt.axhline(y=0, color="gray")
plt.axvline(x=0, color="gray")
plt.fill_between(np.arange(-1, 2, 0.1), integral_y, facecolor='red')
plt.show()

# %% [markdown]
# グラフが描けたら方程式を計算します。$$\int_{-1}^2 (\frac{8}{3}x^3+x-1)dx$$

# %%
print(sympy.integrate((8 / 3) * x ** 3 + x - 1, (x, -1, 2)))
